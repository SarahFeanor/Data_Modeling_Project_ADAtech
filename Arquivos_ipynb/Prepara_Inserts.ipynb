# %%
import pandas as pd

AmostraFipe = pd.read_csv('fipe_2023_amostra.csv', encoding='utf-8', sep=',')
FATO_FIPE = AmostraFipe[['Mes_Ref','Modelo','Ano_Modelo','Preco_Medio','Autenticacao','Data_Consulta']]

# %%
def trataTexto(txt):
    try:
        if txt == '':
            return 'NULL'
        else:
            return"'"+txt+"'"
    except:
        return 'NULL'
print(trataTexto('teste'))
# Out:
# 'teste'

# %%
def trataDateRefFipe(txt):
    mes_replace= {'janeiro':'01', 'fevereiro':'02', 'março':'03', 'abril':'04', 'maio':'05', 'junho':'06', 'julho':'07',
             'agosto':'08', 'setembro':'09', 'outubro':'10', 'novembro':'11', 'dezembro':'12'
             }
    try:
        mesDesc, ano = txt.split('/')
        mes = mes_replace.get(mesDesc)

        if mes:
            return trataTexto(ano+'-'+mes+'-'+'01')
        else:
            return 'NULL'
    except:
        return 'NULL'
    
trataDateRefFipe('janeiro/2000')
# Out:
# "'2000-01-01'"

# %%
def trataAno_Modelo(txt):
    try:
        #ano, combustivel = txt.split(' ')
        lista =  txt.split(' ')
        if lista[0] == 'Zero':
            ano = '0'
            combustivel = lista[2]
        else:
            ano = lista[0]
            combustivel = lista[1]
        return int(ano), trataTexto(combustivel)
    except:
        return 'NULL'

trataAno_Modelo('2018 Gasolina')
# Out:
# (2018, "'Gasolina'")

# %%
def trataPreco(txt):
    try:
        txt=txt.replace('R$ ','')
        txt=txt.replace(',00','')
        txt=txt.replace('.','')
        return int(txt)
    except:
        return 'NULL'
    
trataPreco('R$ 12.853,00')
# Out:
# 12853

# %%
def trataDataConsulta(txt):
    mes_replace= {'janeiro':'01', 'fevereiro':'02', 'março':'03', 'abril':'04', 'maio':'05', 'junho':'06', 'julho':'07',
             'agosto':'08', 'setembro':'09', 'outubro':'10', 'novembro':'11', 'dezembro':'12'
             }
    try:
        list = txt.split(' ')
        mes = mes_replace.get(list[3])
        dia = int(list[1])
        if dia < 10:
            dia_txt = '0'+list[1]
        else:
            dia_txt = list[1]
        if mes:
            return trataTexto(list[5]+'-'+mes+'-'+dia_txt+' '+list[6]+':00')
        else:
            return 'NULL'
    except:
        return 'NULL'
    
    
trataDataConsulta('sábado, 2 de dezembro de 2023 15:30')
# Out:
# "'2023-12-02 15:30:00'"

# %%
inicioInsert='''INSERT INTO fato_fipe
VALUES
'''
with open('insert_fato_fipe.txt', 'a',encoding="utf-8") as file:
    file.write(inicioInsert)
    file.close()

    
tamanho = len(FATO_FIPE)
for row in FATO_FIPE.iterrows():
    data = trataDateRefFipe(row[1][0])
    modelo = trataTexto(row[1][1])
    ano_modelo, combustivel = trataAno_Modelo(row[1][2])
    preco=trataPreco(row[1][3])
    validacao = trataTexto(row[1][4])
    data_consulta = trataDataConsulta(row[1][5])
    
    linhaTratada = f"({data},{modelo},{ano_modelo},{combustivel},{preco},{validacao},{data_consulta})" 
    if row[0] < tamanho-1:
        linhaTratada = linhaTratada+',\n'
    else:
        linhaTratada = linhaTratada+';'
    with open('insert_fato_fipe.txt', 'a',encoding="utf-8") as file:
        file.write(linhaTratada)            
        file.close()

# %%
DIM_FIPE_MARCA_MODELO = AmostraFipe.groupby(['Modelo','Marca','Cod_FIPE']).count()#[['Modelo','Marca','Cod_FIPE']]

DIM_FIPE_MARCA_MODELO
# Out:
#                                                                Mes_Ref  \
# Modelo                               Marca           Cod_FIPE
# 100 2.8 V6                           Audi            008030-6        9
# 100 2.8 V6 Avant                     Audi            008076-4        6
# 100 S-4 2.2 Avant Turbo              Audi            008031-4        6
# 116iA 1.6 TB 16V 136cv 5p            BMW             009171-5       12
# 118i M Sport 1.5 TB 12V Aut. 5p      BMW             009298-3        9
# ...                                                                ...
# up! move I MOTION 1.0 T. Flex 12V 3p VW - VolksWagen 005372-4        6
# up! move I MOTION 1.0 T. Flex 12V 5p VW - VolksWagen 005399-6       15
# up! take 1.0 T. Flex 12V 3p          VW - VolksWagen 005376-7       12
# up! take 1.0 Total Flex 12V 5p       VW - VolksWagen 005365-1       18
# up! track 1.0 Total Flex 12V 5p      VW - VolksWagen 005468-2        3
#
#                                                                Ano_Modelo  \
# Modelo                               Marca           Cod_FIPE
# 100 2.8 V6                           Audi            008030-6           9
# 100 2.8 V6 Avant                     Audi            008076-4           6
# 100 S-4 2.2 Avant Turbo              Audi            008031-4           6
# 116iA 1.6 TB 16V 136cv 5p            BMW             009171-5          12
# 118i M Sport 1.5 TB 12V Aut. 5p      BMW             009298-3           9
# ...                                                                   ...
# up! move I MOTION 1.0 T. Flex 12V 3p VW - VolksWagen 005372-4           6
# up! move I MOTION 1.0 T. Flex 12V 5p VW - VolksWagen 005399-6          15
# up! take 1.0 T. Flex 12V 3p          VW - VolksWagen 005376-7          12
# up! take 1.0 Total Flex 12V 5p       VW - VolksWagen 005365-1          18
# up! track 1.0 Total Flex 12V 5p      VW - VolksWagen 005468-2           3
#
#                                                                Autenticacao  \
# Modelo                               Marca           Cod_FIPE
# 100 2.8 V6                           Audi            008030-6             9
# 100 2.8 V6 Avant                     Audi            008076-4             6
# 100 S-4 2.2 Avant Turbo              Audi            008031-4             6
# 116iA 1.6 TB 16V 136cv 5p            BMW             009171-5            12
# 118i M Sport 1.5 TB 12V Aut. 5p      BMW             009298-3             9
# ...                                                                     ...
# up! move I MOTION 1.0 T. Flex 12V 3p VW - VolksWagen 005372-4             6
# up! move I MOTION 1.0 T. Flex 12V 5p VW - VolksWagen 005399-6            15
# up! take 1.0 T. Flex 12V 3p          VW - VolksWagen 005376-7            12
# up! take 1.0 Total Flex 12V 5p       VW - VolksWagen 005365-1            18
# up! track 1.0 Total Flex 12V 5p      VW - VolksWagen 005468-2             3
#
#                                                                Data_Consulta  \
# Modelo                               Marca           Cod_FIPE
# 100 2.8 V6                           Audi            008030-6              9
# 100 2.8 V6 Avant                     Audi            008076-4              6
# 100 S-4 2.2 Avant Turbo              Audi            008031-4              6
# 116iA 1.6 TB 16V 136cv 5p            BMW             009171-5             12
# 118i M Sport 1.5 TB 12V Aut. 5p      BMW             009298-3              9
# ...                                                                      ...
# up! move I MOTION 1.0 T. Flex 12V 3p VW - VolksWagen 005372-4              6
# up! move I MOTION 1.0 T. Flex 12V 5p VW - VolksWagen 005399-6             15
# up! take 1.0 T. Flex 12V 3p          VW - VolksWagen 005376-7             12
# up! take 1.0 Total Flex 12V 5p       VW - VolksWagen 005365-1             18
# up! track 1.0 Total Flex 12V 5p      VW - VolksWagen 005468-2              3
#
#                                                                Preco_Medio
# Modelo                               Marca           Cod_FIPE
# 100 2.8 V6                           Audi            008030-6            9
# 100 2.8 V6 Avant                     Audi            008076-4            6
# 100 S-4 2.2 Avant Turbo              Audi            008031-4            6
# 116iA 1.6 TB 16V 136cv 5p            BMW             009171-5           12
# 118i M Sport 1.5 TB 12V Aut. 5p      BMW             009298-3            9
# ...                                                                    ...
# up! move I MOTION 1.0 T. Flex 12V 3p VW - VolksWagen 005372-4            6
# up! move I MOTION 1.0 T. Flex 12V 5p VW - VolksWagen 005399-6           15
# up! take 1.0 T. Flex 12V 3p          VW - VolksWagen 005376-7           12
# up! take 1.0 Total Flex 12V 5p       VW - VolksWagen 005365-1           18
# up! track 1.0 Total Flex 12V 5p      VW - VolksWagen 005468-2            3
#
# [2508 rows x 5 columns]

# %%
inicioInsert='''INSERT INTO dim_fipe_marca_modelo
VALUES
'''
with open('insert_dim_fipe_marca_modelo.txt', 'a',encoding="utf-8") as file:
    file.write(inicioInsert)
    file.close()

    
tamanho = len(DIM_FIPE_MARCA_MODELO)

for index,row in enumerate(DIM_FIPE_MARCA_MODELO.index):
    modelo = trataTexto(row[0])
    marca = trataTexto(row[1])
    cod_fipe = trataTexto(row[2])
    
    linhaTratada = f"({modelo},{marca},{cod_fipe})" 
    if index < tamanho-1:
        linhaTratada = linhaTratada+',\n'
    else:
        linhaTratada = linhaTratada+';'
    with open('insert_dim_fipe_marca_modelo.txt', 'a',encoding="utf-8") as file:
        file.write(linhaTratada)            
        file.close()

# %%
AmostraDadosTecnicos = pd.read_csv('tabela_tratada .csv', encoding='utf-8', sep=',')
AmostraDadosTecnicos
# Out:
#     Marca   Familia  Ano_Modelo                                    Modelo  \
# 0    Ford    Fiesta        2016         Fiesta TITANIUM 1.6 16V Flex Mec.
# 1   Honda     Civic        2014   Civic Sedan LXR 2.0 Flexone 16V Aut. 4p
# 2    Audi  A3 Sedan        2020    A3 Sedan Performance 2.0 TFSI S-tronic
# 3    Ford    Ranger        2003  Ranger XLT 2.8 8v 135cv 4x4 CD TB Diesel
# 4    Audi        Q7        2011   Q7 3.0 V6 TFSI Quat.Tip.5p/ Perf.(Híb.)
# ..    ...       ...         ...                                       ...
# 81   Ford   Courier        2001                      Courier Sport 1.6 8v
# 82   Audi        Q7        2022   Q7 Perf. Black 3.0 TFSI Quat.Tip.(Híb.)
# 83    BMW      760i        2003                 760iL 6.0 V12 445cv/544cv
# 84   Audi  A3 Sedan        2016  A3 Sed. Ambition 2.0 TSFI 220cv S-tronic
# 85   Ford    Ranger        2005     Ranger XLS 2.3 16V 145cv/150cv 4x2 CD
#
#    Configuração Combustível  Lugares  Portas     Porte Procedência  \
# 0         Hatch        Flex        5       4  Compacto    Nacional
# 1          Sedã        Flex        5       4     Médio    Nacional
# 2          Sedã    Gasolina        5       4     Médio    Nacional
# 3        Picape      Diesel        5       4     Médio   Importado
# 4           SUV    Gasolina        7       4    Grande   Importado
# ..          ...         ...      ...     ...       ...         ...
# 81       Picape    Gasolina        2       2  Compacto    Nacional
# 82          SUV    Gasolina        7       4    Grande   Importado
# 83         Sedã    Gasolina        5       4    Grande   Importado
# 84         Sedã    Gasolina        5       4     Médio   Importado
# 85       Picape    Gasolina        6       4     Médio   Importado
#
#        Propulsão
# 0      Combustão
# 1      Combustão
# 2      Combustão
# 3      Combustão
# 4            NaN
# ..           ...
# 81     Combustão
# 82  Híbrido leve
# 83     Combustão
# 84     Combustão
# 85     Combustão
#
# [86 rows x 11 columns]

# %%
DIM_DADOS_TECNICOS_MODELO = AmostraDadosTecnicos.groupby(['Modelo','Marca','Familia', 'Configuração','Lugares','Portas','Porte','Propulsão'],dropna=False).count()

DIM_DADOS_TECNICOS_MODELO.head(30)
# Out:
#                                                                                                                  Ano_Modelo  \
# Modelo                                   Marca Familia        Configuração Lugares Portas Porte       Propulsão
# 118i Sport 1.5 TB 12V Aut. 5p            BMW   118i           Hatch        5       4      Médio       Combustão           1
# 316i 1.6 TB 16V 136cv 4p                 BMW   316i           Sedã         5       4      Médio       Combustão           1
# 318i Cabrio 1.8 16V                      BMW   318i Cabriolet Conversível  4       2      Médio       Combustão           1
# 320iA                                    BMW   320i           Sedã         5       4      Médio       Combustão           1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   BMW   320i           Sedã         5       4      Médio       Combustão           2
# 325i                                     BMW   325i           Sedã         5       4      Médio       Combustão           1
# 325iA                                    BMW   325i           Sedã         5       4      Médio       Combustão           1
# 330i Sport 2.0 TB 16V 4p                 BMW   330i           Sedã         5       4      Médio       Combustão           1
# 500 Cult 1.4 Flex 8V EVO Dualogic        Fiat  500            Hatch        4       2      Subcompacto Combustão           1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     BMW   535i           Sedã         5       4      Grande      Combustão           1
# 550iA 4.8 32V                            BMW   550i           Sedã         5       4      Grande      Combustão           1
# 760iL 6.0 V12 445cv/544cv                BMW   760i           Sedã         5       4      Grande      Combustão           1
# 80 2.0 Avant                             Audi  80 Avant       Perua        5       4      Médio       Combustão           1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic Audi  A3 Sedan       Sedã         5       4      Médio       Combustão           1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) Audi  A3 Sedan       Sedã         5       4      Médio       NaN                 1
# A3 Sedan Performance 2.0 TFSI S-tronic   Audi  A3 Sedan       Sedã         5       4      Médio       Combustão           1
# 80 2.0 Avant                             Audi  80 Avant       Perua        5       4      Médio       Combustão            1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic Audi  A3 Sedan       Sedã         5       4      Médio       Combustão            1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) Audi  A3 Sedan       Sedã         5       4      Médio       NaN                  1
# A3 Sedan Performance 2.0 TFSI S-tronic   Audi  A3 Sedan       Sedã         5       4      Médio       Combustão            1
# A4 2.8 Avant V6 30V Tiptronic            Audi  A4 Avant       Perua        5       4      Médio       Combustão            1
# ARGO DRIVE 1.0 6V Flex                   Fiat  Argo           Hatch        5       4      Compacto    Combustão            1
# ARGO DRIVE 1.3 8V Flex                   Fiat  Argo           Hatch        5       4      Compacto    Combustão            1
# CITY Hatchback Touring 1.5 Flex 16V Aut  Honda City Hatch     Hatch        5       4      Compacto    Combustão            1
# CITY Sedan DX 1.5 Flex 16V Mec.          Honda City           Sedã         5       4      Compacto    Combustão            1
# CR-V 2.0 16V Aut.                        Honda Cr-v           SUV          5       4      Médio       Combustão            1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    Honda Cr-v           SUV          5       4      Médio       Combustão            2
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  Honda Civic          Sedã         5       4      Médio       Combustão            1
# Coupe 16V                                Fiat  Coupe          Cupê         4       2      Médio       Combustão            1
# Courier Sport 1.6 8v                     Ford  Courier        Picape       2       2      Compacto    Combustão            1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     Fiat  Doblo          Minivan      6       4      Médio       Combustão            1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    Fiat  Doblo          Minivan      6       4      Médio       Combustão            1
# Doblo Cargo 1.8 mpi Fire Flex 8V/16V 4p  Fiat  Doblo          Furgão       2       3      Médio       Combustão            1
# Doblo ESSENCE 1.8 Flex 16V 5p            Fiat  Doblo          Minivan      7       4      Médio       Combustão            1

# %%
inicioInsert='''INSERT INTO dim_dados_tecnicos_modelo
VALUES
'''
with open('insert_dim_dados_tecnicos_modelo.txt', 'a',encoding="utf-8") as file:
    file.write(inicioInsert)
    file.close()

    
tamanho = len(DIM_DADOS_TECNICOS_MODELO)

for index,row in enumerate(DIM_DADOS_TECNICOS_MODELO.index):
    modelo = trataTexto(row[0])
    marca = trataTexto(row[1])
    familia = trataTexto(row[2])
    configuracao = trataTexto(row[3])
    lugares = row[4]
    portas = row[5]
    porte = trataTexto(row[6])
    propulsao = trataTexto(row[7])
    

    linhaTratada = f"({modelo},{marca},{familia},{configuracao},{lugares},{portas},{porte},{propulsao})" 
    if index < tamanho-1:
        linhaTratada = linhaTratada+',\n'
    else:
        linhaTratada = linhaTratada+';'
    with open('insert_dim_dados_tecnicos_modelo.txt', 'a',encoding="utf-8") as file:
        file.write(linhaTratada)            
        file.close()

# %%
DIM_DADOS_TECNICOS_ANO_MODELO = AmostraDadosTecnicos.groupby(['Modelo','Ano_Modelo','Combustível', 'Procedência'],dropna=False).count()

# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional           1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado          1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado          1
# 550iA 4.8 32V                            2009       Gasolina    Importado          1
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado          1
# 80 2.0 Avant                             1995       Gasolina    Importado          1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado          1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional           1
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional           1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado          1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional           1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional           1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional           1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional           1
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado          1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado          1
#                                          2016       Flex        Importado          1
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional           1
# Coupe 16V                                1996       Gasolina    Importado          1
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional           1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional           1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional           1
#
#                                                                              Configuração  \
# Modelo                                   Ano_Modelo Combustível Procedência
# 118i Sport 1.5 TB 12V Aut. 5p            2020       Gasolina    Importado               1
# 316i 1.6 TB 16V 136cv 4p                 2015       Gasolina    Importado               1
# 318i Cabrio 1.8 16V                      1994       Gasolina    Importado               1
# 320iA                                    2003       Gasolina    Importado               1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   2018       Flex        Nacional                1
#                                          2020       Gasolina    Nacional                1
# 325i                                     1995       Gasolina    Importado               1
# 325iA                                    2012       Gasolina    Importado               1
# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional                1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado               1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado               1
# 550iA 4.8 32V                            2009       Gasolina    Importado               1
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado               1
# 80 2.0 Avant                             1995       Gasolina    Importado               1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado               1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional                1
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional                1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado               1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional                1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional                1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional                1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional                1
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado               1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado               1
#                                          2016       Flex        Importado               1
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional                1
# Coupe 16V                                1996       Gasolina    Importado               1
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional                1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional                1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional                1
#
#                                                                              Lugares  \
# Modelo                                   Ano_Modelo Combustível Procedência
# 118i Sport 1.5 TB 12V Aut. 5p            2020       Gasolina    Importado          1
# 316i 1.6 TB 16V 136cv 4p                 2015       Gasolina    Importado          1
# 318i Cabrio 1.8 16V                      1994       Gasolina    Importado          1
# 320iA                                    2003       Gasolina    Importado          1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   2018       Flex        Nacional           1
#                                          2020       Gasolina    Nacional           1
# 325i                                     1995       Gasolina    Importado          1
# 325iA                                    2012       Gasolina    Importado          1
# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional           1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado          1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado          1
# 550iA 4.8 32V                            2009       Gasolina    Importado          1
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado          1
# 80 2.0 Avant                             1995       Gasolina    Importado          1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado          1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional           1
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional           1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado          1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional           1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional           1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional           1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional           1
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado          1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado          1
#                                          2016       Flex        Importado          1
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional           1
# Coupe 16V                                1996       Gasolina    Importado          1
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional           1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional           1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional           1
#
#                                                                              Portas  \
# Modelo                                   Ano_Modelo Combustível Procedência
# 118i Sport 1.5 TB 12V Aut. 5p            2020       Gasolina    Importado         1
# 316i 1.6 TB 16V 136cv 4p                 2015       Gasolina    Importado         1
# 318i Cabrio 1.8 16V                      1994       Gasolina    Importado         1
# 320iA                                    2003       Gasolina    Importado         1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   2018       Flex        Nacional          1
#                                          2020       Gasolina    Nacional          1
# 325i                                     1995       Gasolina    Importado         1
# 325iA                                    2012       Gasolina    Importado         1
# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional          1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado         1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado         1
# 550iA 4.8 32V                            2009       Gasolina    Importado         1
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado         1
# 80 2.0 Avant                             1995       Gasolina    Importado         1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado         1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional          1
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional          1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado         1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional          1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional          1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional          1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional          1
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado         1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado         1
#                                          2016       Flex        Importado         1
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional          1
# Coupe 16V                                1996       Gasolina    Importado         1
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional          1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional          1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional          1
#
#                                                                              Porte  \
# Modelo                                   Ano_Modelo Combustível Procedência
# 118i Sport 1.5 TB 12V Aut. 5p            2020       Gasolina    Importado        1
# 316i 1.6 TB 16V 136cv 4p                 2015       Gasolina    Importado        1
# 318i Cabrio 1.8 16V                      1994       Gasolina    Importado        1
# 320iA                                    2003       Gasolina    Importado        1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   2018       Flex        Nacional         1
#                                          2020       Gasolina    Nacional         1
# 325i                                     1995       Gasolina    Importado        1
# 325iA                                    2012       Gasolina    Importado        1
# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional         1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado        1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado        1
# 550iA 4.8 32V                            2009       Gasolina    Importado        1
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado        1
# 80 2.0 Avant                             1995       Gasolina    Importado        1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado        1
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional         1
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional         1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado        1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional         1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional         1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional         1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional         1
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado        1
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado        1
#                                          2016       Flex        Importado        1
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional         1
# Coupe 16V                                1996       Gasolina    Importado        1
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional         1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional         1
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional         1
#
#                                                                              Propulsão
# Modelo                                   Ano_Modelo Combustível Procedência
# 118i Sport 1.5 TB 12V Aut. 5p            2020       Gasolina    Importado            1
# 316i 1.6 TB 16V 136cv 4p                 2015       Gasolina    Importado            0
# 318i Cabrio 1.8 16V                      1994       Gasolina    Importado            1
# 320iA                                    2003       Gasolina    Importado            1
# 320iA Modern/Sport TB 2.0/A.Flex/GP 4p   2018       Flex        Nacional             1
#                                          2020       Gasolina    Nacional             1
# 325i                                     1995       Gasolina    Importado            0
# 325iA                                    2012       Gasolina    Importado            0
# 330i Sport 2.0 TB 16V 4p                 2020       Gasolina    Nacional             1
# 500 Cult 1.4 Flex 8V EVO Dualogic        2013       Flex        Importado            1
# 535iA M Sport 3.0 24V 306cv Bi-Turbo     2016       Gasolina    Importado            0
# 550iA 4.8 32V                            2009       Gasolina    Importado            0
# 760iL 6.0 V12 445cv/544cv                2003       Gasolina    Importado            0
# 80 2.0 Avant                             1995       Gasolina    Importado            1
# A3 Sed. Ambition 2.0 TSFI 220cv S-tronic 2016       Gasolina    Importado            0
# A3 Sed.Perf. Black 2.0 TFSI S-tr. (Hib.) 2021       Gasolina    Nacional             0
# A3 Sedan Performance 2.0 TFSI S-tronic   2020       Gasolina    Nacional             1
# A4 2.8 Avant V6 30V Tiptronic            2000       Gasolina    Importado            1
# ARGO DRIVE 1.0 6V Flex                   2021       Flex        Nacional             1
# ARGO DRIVE 1.3 8V Flex                   2020       Flex        Nacional             1
# CITY Hatchback Touring 1.5 Flex 16V Aut  2022       Flex        Nacional             1
# CITY Sedan DX 1.5 Flex 16V Mec.          2017       Flex        Nacional             0
# CR-V 2.0 16V Aut.                        2007       Gasolina    Importado            0
# CR-V EXL 2.0 16V 4WD/2.0 Flexone Aut.    2008       Gasolina    Importado            0
#                                          2016       Flex        Importado            0
# Civic Sedan LXR 2.0 Flexone 16V Aut. 4p  2014       Flex        Nacional             1
# Coupe 16V                                1996       Gasolina    Importado            0
# Courier Sport 1.6 8v                     2001       Gasolina    Nacional             1
# Doblo ATTRACTIVE 1.4 Fire Flex 8V 5p     2014       Flex        Nacional             0
# Doblo Adv/Adv TRYON/LOCKER 1.8 Flex\t    2019       Flex        Nacional             0

# %%
inicioInsert='''INSERT INTO dim_dados_tecnicos_ano_modelo
VALUES
'''
with open('insert_dim_dados_tecnicos_ano_modelo.txt', 'a',encoding="utf-8") as file:
    file.write(inicioInsert)
    file.close()

    
tamanho = len(DIM_DADOS_TECNICOS_ANO_MODELO)

for index,row in enumerate(DIM_DADOS_TECNICOS_ANO_MODELO.index):
    modelo = trataTexto(row[0])
    ano_modelo = row[1]
    combustivel = trataTexto(row[2])
    if row[2]=='Diesel' or row[2]=='Álcool':
        combustivel_fipe = combustivel
    else:
        combustivel_fipe = "'Gasolina'"
    procedencia = trataTexto(row[3])

    linhaTratada = f"({modelo},{ano_modelo},{combustivel},{combustivel_fipe},{procedencia})" 
    if index < tamanho-1:
        linhaTratada = linhaTratada+',\n'
    else:
        linhaTratada = linhaTratada+';'
    with open('insert_dim_dados_tecnicos_ano_modelo.txt', 'a',encoding="utf-8") as file:
        file.write(linhaTratada)            
        file.close()

# %%
AmostraSalarioMinimo = pd.read_csv('Ipeadata_Tratado.csv', encoding='utf-8', sep=',')
AmostraSalarioMinimo
# Out:
#            Data  Salario_Minimo_Vigente
# 0    2000-01-01                     136
# 1    2000-02-01                     136
# 2    2000-03-01                     136
# 3    2000-04-01                     151
# 4    2000-05-01                     151
# ..          ...                     ...
# 283  2023-08-01                    1320
# 284  2023-09-01                    1320
# 285  2023-10-01                    1320
# 286  2023-11-01                    1320
# 287  2023-12-01                    1320
#
# [288 rows x 2 columns]

# %%
inicioInsert='''INSERT INTO fato_salario_minimo
VALUES
'''
with open('insert_fato_salario_minimo.txt', 'a',encoding="utf-8") as file:
    file.write(inicioInsert)
    file.close()

    
tamanho = len(AmostraSalarioMinimo)
for row in AmostraSalarioMinimo.iterrows():
    data = trataTexto(row[1][0])
    valor = row[1][1]
    
    linhaTratada = f"({data},{valor})" 
    if row[0] < tamanho-1:
        linhaTratada = linhaTratada+',\n'
    else:
        linhaTratada = linhaTratada+';'
    with open('insert_fato_salario_minimo.txt', 'a',encoding="utf-8") as file:
        file.write(linhaTratada)            
        file.close()
